# %% [markdown]
# # Predicting Taxi duration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# ## Reading taxi data
# Data - https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# ### Data Dictionary
# https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_green.pdf

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet')
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1         2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2         2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3         1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4         2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           236           239              1.0           1.98
# 1         1.0            65           170              5.0           6.54
# 2         1.0            74           262              1.0           3.08
# 3         1.0            74           116              1.0           2.40
# 4         1.0            74           243              1.0           5.14
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %% [markdown]
# - Create trip duration as feature
# - Going only with trip type = dispatch

# %%
df['duration'] = (df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']).dt.total_seconds() / 60
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
# df = df[df.trip_type == 2] #filtering only dispatch taxis
df.trip_type.value_counts()
# Out:
# trip_type
# 1.0    51397
# 2.0     1736
# Name: count, dtype: int64

# %%
sns.displot(df.duration, height=5, aspect=5)

# %%
sns.set_style("whitegrid")  # Optional: Set the style of the plot

# Adjusting the size of the figure
plt.figure(figsize=(20, 5))

# Plotting the box plot
sns.boxplot(data=df, x='duration')

# Adding labels and title
plt.xlabel('Trip Duration (minutes)')
plt.title('Distribution of Trip Duration')

# Show the plot
plt.show()

# %%
import scipy.stats as stats
import pylab

# Create a Q-Q plot

stats.probplot(df['duration'], dist="norm", plot=pylab)
pylab.show()

# %%
df.duration.describe(percentiles=[0.95, 0.98,0.99])
# Out:
# count    56551.000000
# mean        18.171379
# std         75.464751
# min          0.000000
# 50%         11.400000
# 95%         33.683333
# 98%         46.816667
# 99%         59.825000
# max       1438.983333
# Name: duration, dtype: float64

# %%
df = df[(df.duration >=1 ) & (df.duration <= 60)]
df

#50% of the trips are within 1 min and 60 mins - for dispatch taxis only 
# most of the trips are less than 1 mins
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
# think of what numerical and ctegorical vairbles we can use.
# vendor 

categorical = ['PULocationID','DOLocationID']
numerical = ['trip_distance']

# %%
df[categorical].dtypes
# Out:
# PULocationID    int32
# DOLocationID    int32
# dtype: object

# %%
df.loc[:, categorical] = df.loc[:, categorical].astype(str)

# %%
df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                     object
# DOLocationID                     object
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# duration                        float64
# dtype: object

# %%
dv = DictVectorizer()

# %%
train_dict = df[categorical + numerical].to_dict(orient='records')

# %%
X_train = dv.fit_transform(train_dict)

# %%
X_train
# Out:
# <54373x449 sparse matrix of type '<class 'numpy.float64'>'
# 	with 163119 stored elements in Compressed Sparse Row format>

# %%
target = 'duration'
y_train = df[target].values
y_train
# Out:
# array([11.5       , 20.86666667, 19.03333333, ...,  4.        ,
#         6.        , 31.        ])

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
sns.displot(y_pred, label = 'predcition')
sns.displot(y_train, label='actual')

plt.legend()

# %%
root_mean_squared_error(y_train, y_pred)
# Out:
# 7.1228222122750955

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet')
df_val = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (54373, 51497)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
lasso = Lasso()
lasso.fit(X_train, y_train)

y_pred = lasso.predict(X_train)

# %%
root_mean_squared_error(y_train, y_pred)
# Out:
# 9.019532867192334
